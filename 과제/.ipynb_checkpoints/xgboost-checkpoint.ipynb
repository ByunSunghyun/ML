# %%
import sys
import sktime
import tqdm as tq
import xgboost as xgb
import matplotlib
import seaborn as sns
import sklearn as skl
import pandas as pd
import numpy as np
print("-------------------------- Python & library version --------------------------")
print("Python version: {}".format(sys.version))
print("pandas version: {}".format(pd.__version__))
print("numpy version: {}".format(np.__version__))
print("matplotlib version: {}".format(matplotlib.__version__))
print("tqdm version: {}".format(tq.__version__))
print("sktime version: {}".format(sktime.__version__))
print("xgboost version: {}".format(xgb.__version__))
print("seaborn version: {}".format(sns.__version__))
print("scikit-learn version: {}".format(skl.__version__))
print("------------------------------------------------------------------------------")
# Out:
# -------------------------- Python & library version --------------------------
# Python version: 3.9.16 (main, Mar  8 2023, 10:39:24) [MSC v.1916 64 bit (AMD64)]
# pandas version: 1.5.3
# numpy version: 1.25.0
# matplotlib version: 3.7.1
# tqdm version: 4.65.0
# sktime version: 0.20.0
# xgboost version: 1.7.3
# seaborn version: 0.12.2
# scikit-learn version: 1.2.2
# ------------------------------------------------------------------------------

# %%
import matplotlib.pyplot as plt
from tqdm import tqdm
from sktime.forecasting.model_selection import temporal_train_test_split
from sklearn.model_selection import GridSearchCV
import time
from xgboost import XGBRegressor

pd.set_option('display.max_columns', 30)

# %%
train = pd.read_excel('Train_dataset.xlsx')
answer = pd.read_excel('Answer_sheet.xlsx')
weather = pd.read_csv('weather.csv', encoding='CP949')

train = pd.concat([train, answer], axis=0)

weather.rename(columns={"일시": "Time", "기온(°C)":"Temp", "풍속(m/s)": "WS", "습도(%)":"HMD", "일조(hr)": "Sun", "강수량(mm)": "prec"}, inplace=True)
weather['HMD'] = weather['HMD'].interpolate(method='linear')
weather['Temp'] = weather['Temp'].interpolate(method='linear')
weather = weather[['Time', "Temp", "HMD", "WS", "Sun", "prec"]]

weather['Time'] = pd.to_datetime(weather['Time'], format='%Y-%m-%d %H:%M')
train['Time'] = pd.to_datetime(train['Time'], format='%Y%m%d_%H')
answer['Time'] = pd.to_datetime(answer['Time'], format='%Y%m%d_%H')

weather = weather.fillna(0)

train = train.sort_values(by='Time')

train = pd.merge(train, weather, on='Time', how='inner')
answer = pd.merge(answer, weather, on='Time', how='inner')

# %%
display(train)
# Out:
#                     Time    Power  Temp   HMD   WS  Sun  prec
# 0    2018-01-01 00:00:00  105.760  -2.2  70.0  1.4  0.0   0.0
# 1    2018-01-01 01:00:00  104.944  -2.5  67.0  1.5  0.0   0.0
# 2    2018-01-01 02:00:00  105.552  -2.9  63.0  0.9  0.0   0.0
# 3    2018-01-01 03:00:00  108.512  -3.0  64.0  0.7  0.0   0.0
# 4    2018-01-01 04:00:00  102.896  -3.4  73.0  0.9  0.0   0.0
# ...                  ...      ...   ...   ...  ...  ...   ...
# 8731 2018-12-31 19:00:00  149.632  -2.8  45.0  1.2  0.0   0.0
# 8732 2018-12-31 20:00:00  154.624  -3.5  47.0  1.2  0.0   0.0
# 8733 2018-12-31 21:00:00  162.688  -4.0  51.0  0.1  0.0   0.0
# 8734 2018-12-31 22:00:00      NaN  -4.6  58.0  1.1  0.0   0.0
# 8735 2018-12-31 23:00:00  137.216  -5.2  59.0  0.4  0.0   0.0
#
# [8736 rows x 7 columns]

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8736 entries, 0 to 8735
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Time    8736 non-null   datetime64[ns]
#  1   Power   7863 non-null   float64
#  2   Temp    8736 non-null   float64
#  3   HMD     8736 non-null   float64
#  4   WS      8736 non-null   float64
#  5   Sun     8736 non-null   float64
#  6   prec    8736 non-null   float64
# dtypes: datetime64[ns](1), float64(6)
# memory usage: 546.0 KB

# %%
answer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 873 entries, 0 to 872
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Time    873 non-null    datetime64[ns]
#  1   Temp    873 non-null    float64
#  2   HMD     873 non-null    float64
#  3   WS      873 non-null    float64
#  4   Sun     873 non-null    float64
#  5   prec    873 non-null    float64
# dtypes: datetime64[ns](1), float64(5)
# memory usage: 47.7 KB

# %%
def make_time(data):
    cols = ['date_time', 'power', 'temp', 'hum', 'wind','sun', 'prec']
    data.columns = cols
    # 시간 관련 변수들 생성
    date = pd.to_datetime(data.date_time)
    data['hour'] = date.dt.hour
    data['day'] = date.dt.weekday
    data['month'] = date.dt.month
    data['week'] = date.dt.weekofyear

# %%
def remove_outlier(d_cp, column):
    fraud_column_data = d_cp[column]
    quan_25 = np.percentile(fraud_column_data.values, 25)
    quan_75 = np.percentile(fraud_column_data.values, 75)

    iqr = quan_75 - quan_25
    iqr_weight = iqr * 1.5
    lowest = quan_25 - iqr_weight
    highest = quan_75 + iqr_weight

    outlier_index = fraud_column_data[(fraud_column_data < lowest) | (fraud_column_data > highest)].index
    d_cp.drop(outlier_index, axis=0, inplace=True)
    return d_cp

# %%
def replace_outlier_with_zero(d_cp, column):
    fraud_column_data = d_cp[column]
    quan_25 = np.percentile(fraud_column_data.values, 25)
    quan_75 = np.percentile(fraud_column_data.values, 75)

    iqr = quan_75 - quan_25
    iqr_weight = iqr * 1.5
    lowest = quan_25 - iqr_weight
    highest = quan_75 + iqr_weight

    outlier_index = fraud_column_data[(fraud_column_data < lowest) | (fraud_column_data > highest)].index
    d_cp.loc[outlier_index, column] = 0
    return d_cp

# %%
# train 데이터 프레임에서 Power 값이 앞뒤로 0인 경우에 해당 값을 0으로 변경
train['Power'] = np.where((train['Power'].shift(1) == 0) & (train['Power'].shift(-1) == 0), 0, train['Power'])
                          
# train 데이터 프레임에서 Power 값이 0으로 변경된 시간
zero_time = train.loc[train['Power'] == 0, 'Time']

# answer 데이터 프레임에서 해당 시간의 Power 값을 0으로 변경
# answer.loc[answer['Time'].isin(zero_time), 'Power'] = 0

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8736 entries, 0 to 8735
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Time    8736 non-null   datetime64[ns]
#  1   Power   7868 non-null   float64
#  2   Temp    8736 non-null   float64
#  3   HMD     8736 non-null   float64
#  4   WS      8736 non-null   float64
#  5   Sun     8736 non-null   float64
#  6   prec    8736 non-null   float64
# dtypes: datetime64[ns](1), float64(6)
# memory usage: 546.0 KB

# %%
train = train.dropna()
train = train[train['Power'] != 0]
train = remove_outlier(train,'Power')

# %%
plt.plot(train['Power'], 'ro')

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7237 entries, 0 to 8735
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Time    7237 non-null   datetime64[ns]
#  1   Power   7237 non-null   float64
#  2   Temp    7237 non-null   float64
#  3   HMD     7237 non-null   float64
#  4   WS      7237 non-null   float64
#  5   Sun     7237 non-null   float64
#  6   prec    7237 non-null   float64
# dtypes: datetime64[ns](1), float64(6)
# memory usage: 452.3 KB

# %%
# train = replace_outlier_with_zero(train,'Power')
# train['Power'] = train['Power'].replace(0, np.nan)
# train['Power'] = train['Power'].interpolate(method='linear')

# %%
## 변수들을 영문명으로 변경
cols = ['date_time', 'power', 'temp', 'hum', 'wind','sun', 'prec']
train.columns = cols

# 시간 관련 변수들 생성
date = pd.to_datetime(train.date_time)
train['hour'] = date.dt.hour
train['day'] = date.dt.weekday
train['month'] = date.dt.month
train['week'] = date.dt.isocalendar().week
train['week'] = train['week'].astype(int)

hour_mean = train.groupby(train['hour'])['power'].mean()
train['hour_mean'] = train['hour'].map(hour_mean)

# day_mean = train.groupby(train['day'])['power'].mean()
# train['day_mean'] = train['day'].map(day_mean)

# week_mean = train.groupby(train['week'])['power'].mean()
# train['week_mean'] = train['week'].map(week_mean)

# month_mean = train.groupby(train['month'])['power'].mean()
# train['month_mean'] = train['month'].map(month_mean)

### 공휴일 변수 추가
train['holiday'] = train.apply(lambda x : 0 if x['day']<5 else 1, axis = 1)

## https://dacon.io/competitions/official/235680/codeshare/2366?page=1&dtype=recent
train['sin_time'] = np.sin(2*np.pi*train.hour/24)
train['cos_time'] = np.cos(2*np.pi*train.hour/24)

## https://dacon.io/competitions/official/235736/codeshare/2743?page=1&dtype=recent
train['THI'] = 9/5*train['temp'] - 0.55*(1-train['hum']/100)*(9/5*train['hum']-26)+32

def CDH(xs):
    ys = []
    for i in range(len(xs)):
        if i < 11:
            ys.append(np.sum(xs[:(i+1)]-26))
        else:
            ys.append(np.sum(xs[(i-11):(i+1)]-26))
    return np.array(ys)

train.head()
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7237 entries, 0 to 8735
# Data columns (total 16 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   date_time  7237 non-null   datetime64[ns]
#  1   power      7237 non-null   float64
#  2   temp       7237 non-null   float64
#  3   hum        7237 non-null   float64
#  4   wind       7237 non-null   float64
#  5   sun        7237 non-null   float64
#  6   prec       7237 non-null   float64
#  7   hour       7237 non-null   int64
#  8   day        7237 non-null   int64
#  9   month      7237 non-null   int64
#  10  week       7237 non-null   UInt32
#  11  hour_mean  7237 non-null   float64
#  12  holiday    7237 non-null   int64
#  13  sin_time   7237 non-null   float64
#  14  cos_time   7237 non-null   float64
#  15  THI        7237 non-null   float64
# dtypes: UInt32(1), datetime64[ns](1), float64(10), int64(4)
# memory usage: 940.0 KB

# %%
display(train)
# Out:
#                date_time    power  temp   hum  wind  sun  prec  hour  day  \
# 0    2018-01-01 00:00:00  105.760  -2.2  70.0   1.4  0.0   0.0     0    0
# 1    2018-01-01 01:00:00  104.944  -2.5  67.0   1.5  0.0   0.0     1    0
# 2    2018-01-01 02:00:00  105.552  -2.9  63.0   0.9  0.0   0.0     2    0
# 3    2018-01-01 03:00:00  108.512  -3.0  64.0   0.7  0.0   0.0     3    0
# 4    2018-01-01 04:00:00  102.896  -3.4  73.0   0.9  0.0   0.0     4    0
# ...                  ...      ...   ...   ...   ...  ...   ...   ...  ...
# 8730 2018-12-31 18:00:00  141.440  -1.6  41.0   2.2  0.0   0.0    18    0
# 8731 2018-12-31 19:00:00  149.632  -2.8  45.0   1.2  0.0   0.0    19    0
# 8732 2018-12-31 20:00:00  154.624  -3.5  47.0   1.2  0.0   0.0    20    0
# 8733 2018-12-31 21:00:00  162.688  -4.0  51.0   0.1  0.0   0.0    21    0
# 8735 2018-12-31 23:00:00  137.216  -5.2  59.0   0.4  0.0   0.0    23    0
#
#       month  week   hour_mean  holiday  sin_time      cos_time      THI
# 0         1     1  109.358126        0  0.000000  1.000000e+00  11.5400
# 1         1     1  104.440000        0  0.258819  9.659258e-01  10.3301
# 2         1     1  100.332550        0  0.500000  8.660254e-01   8.9941
# 3         1     1   97.276466        0  0.707107  7.071068e-01   8.9384
# 4         1     1   94.926514        0  0.866025  5.000000e-01  10.2281
# ...     ...   ...         ...      ...       ...           ...      ...
# 8730     12     1  131.326976        0 -1.000000 -1.836970e-16  13.6089
# 8731     12     1  135.631387        0 -0.965926  2.588190e-01  10.3225
# 8732     12     1  136.027923        0 -0.866025  5.000000e-01   8.6181
# 8733     12     1  133.139083        0 -0.707107  7.071068e-01   7.0669
# 8735     12     1  122.329752        0 -0.258819  9.659258e-01   4.5549
#
# [7237 rows x 16 columns]

# %%
## 변수들을 영문명으로 변경
cols = ['date_time', 'temp', 'hum', 'wind', 'sun', 'prec']
answer.columns = cols

# 시간 관련 변수들 생성
date = pd.to_datetime(answer.date_time)
answer['hour'] = date.dt.hour
answer['day'] = date.dt.weekday
answer['month'] = date.dt.month
answer['week'] = date.dt.isocalendar().week
answer['week'] = answer['week'].astype(int)


# answer['hour_mean'] = answer['hour'].map(hour_mean)
# answer['day_mean'] = answer['day'].map(day_mean)
# answer['week_mean'] = answer['week'].map(week_mean)
# answer['month_mean'] = answer['month'].map(month_mean)

### 공휴일 변수 추가
answer['holiday'] = answer.apply(lambda x : 0 if x['day']<5 else 1, axis = 1)

## https://dacon.io/competitions/official/235680/codeshare/2366?page=1&dtype=recent
answer['sin_time'] = np.sin(2*np.pi*answer.hour/24)
answer['cos_time'] = np.cos(2*np.pi*answer.hour/24)

## https://dacon.io/competitions/official/235736/codeshare/2743?page=1&dtype=recent
answer['THI'] = 9/5*answer['temp'] - 0.55*(1-answer['hum']/100)*(9/5*answer['hum']-26)+32

def CDH(xs):
    ys = []
    for i in range(len(xs)):
        if i < 11:
            ys.append(np.sum(xs[:(i+1)]-26))
        else:
            ys.append(np.sum(xs[(i-11):(i+1)]-26))
    return np.array(ys)

answer.drop(['hour', 'date_time'], axis = 1, inplace = True)
train.drop(['hour', 'date_time'], axis = 1, inplace = True)
answer.head()
answer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 873 entries, 0 to 872
# Data columns (total 12 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   temp      873 non-null    float64
#  1   hum       873 non-null    float64
#  2   wind      873 non-null    float64
#  3   sun       873 non-null    float64
#  4   prec      873 non-null    float64
#  5   day       873 non-null    int64
#  6   month     873 non-null    int64
#  7   week      873 non-null    UInt32
#  8   holiday   873 non-null    int64
#  9   sin_time  873 non-null    float64
#  10  cos_time  873 non-null    float64
#  11  THI       873 non-null    float64
# dtypes: UInt32(1), float64(8), int64(3)
# memory usage: 86.1 KB

# %%
# from sklearn.preprocessing import StandardScaler

# exclude_columns = ['power']

# # Select the columns to scale
# columns_to_scale = [col for col in train.columns if col not in exclude_columns]
# df_to_scale = train[columns_to_scale]

# # Fit the scaler on the selected columns
# scaler = StandardScaler()
# scaled_data = scaler.fit_transform(df_to_scale)

# # Create a new DataFrame with the scaled data
# scaled_df = pd.DataFrame(scaled_data, columns=columns_to_scale)

# # Set the index of the scaled DataFrame to match the index of the original DataFrame
# scaled_df.index = train.index

# # Add the excluded columns back to the scaled DataFrame
# scaled_df[exclude_columns] = train[exclude_columns]

# display(scaled_df)
# train = scaled_df
# train.info()

# %%
# # Select the columns to scale
# df_to_scale = answer

# # Fit the scaler on the selected columns
# scaler = StandardScaler()
# scaled_data = scaler.fit_transform(df_to_scale)

# # Create a new DataFrame with the scaled data
# scaled_df = pd.DataFrame(scaled_data, columns=columns_to_scale)
# # scaled_df = pd.DataFrame(scaled_data)

# # Add the excluded columns back to the scaled DataFrame

# display(scaled_df)
# answer = scaled_df
# answer.info()

# %%
## save the preprocessed data
# train.to_csv('./data/train_preprocessed.csv')
# answer.to_excel('tmp.xlsx', index=False)

# %%
## 7번 건물의 발전량
from sklearn.model_selection import train_test_split
features = ['temp', 'hum', 'wind', 'sun', 'prec', 'day', 'month', 'week', 
            'holiday', 'sin_time', 'cos_time', 'THI']
# ''hour_mean', 'day_mean', 'week_mean', 'month_mean', 

df = train

X2 = train[features]
Y2 = train['power']

train, test = train_test_split(df, test_size=0.1)
# test = train[-279:]


X_train = train[features]
Y_train = train['power']

X_test = test[features]
y_test = test['power']

print(X_train.shape)
print(Y_train.shape)
print(X_test.shape)
print(y_test.shape)

# plot_series(y_train, y_test, markers=[',' , ','])
# plt.show()
# Out:
# (6513, 12)
# (6513,)
# (724, 12)
# (724,)

# %%
X2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7237 entries, 0 to 8735
# Data columns (total 12 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   temp      7237 non-null   float64
#  1   hum       7237 non-null   float64
#  2   wind      7237 non-null   float64
#  3   sun       7237 non-null   float64
#  4   prec      7237 non-null   float64
#  5   day       7237 non-null   int64
#  6   month     7237 non-null   int64
#  7   week      7237 non-null   UInt32
#  8   holiday   7237 non-null   int64
#  9   sin_time  7237 non-null   float64
#  10  cos_time  7237 non-null   float64
#  11  THI       7237 non-null   float64
# dtypes: UInt32(1), float64(8), int64(3)
# memory usage: 713.8 KB

# %%
# Define SMAPE loss function
def SMAPE(true, pred):
    return np.mean((np.abs(true-pred))/(np.abs(true) + np.abs(pred))) * 100

# %%
#### alpha를 argument로 받는 함수로 실제 objective function을 wrapping하여 alpha값을 쉽게 조정할 수 있도록 작성했습니다.
# custom objective function for forcing model not to underestimate
def weighted_mse(alpha = 1):
    def weighted_mse_fixed(label, pred):
        residual = (label - pred).astype("float")
        grad = np.where(residual>0, -2*alpha*residual, -2*residual)
        hess = np.where(residual>0, 2*alpha, 2.0)
        return grad, hess
    return weighted_mse_fixed

# %%
# ## Various hyper-parameters to tune

# start_time = time.time()
# xgb1 = XGBRegressor(tree_method='gpu_hist', gpu_id=0, predictor='gpu_predictor')
# parameters = {'objective':['reg:squarederror'],
#               'eval_metric':['rmse'],
#               'gamma':[0, 1, 3, 5],
#               'min_child_weight': [1, 3, 5, 7],
#               'max_depth': [2, 4, 6, 8],
#               'n_estimators': [30, 50, 100, 150],
#               'learning_rate': [0.1, 0.3, 0.5]
#              }
# #
# # 'n_estimators': [30, 50, 100]
# #               'max_depth': [4, 6, 8, 10],
# #               'min_child_weight': [3, 5, 7],
# #               'n_estimators': [30, 50, 100, 200],
# # 'learning_rate': [0.2, 0.5, 1]

# xgb_grid = GridSearchCV(xgb1,
#                         parameters,
#                         cv = 3,
#                         n_jobs = -1,
#                         verbose=2)
 

# xgb_grid.fit(X2, Y2)

# end_time = time.time()

# print(xgb_grid.best_score_)
# print(xgb_grid.best_params_)

# print(f'소요시간: {(end_time - start_time)} 초')

# %%
from sklearn.model_selection import GridSearchCV
from xgboost import XGBRegressor

# Assuming you have a training dataset named X2 and Y2
start_time = time.time()
xgb1 = XGBRegressor(tree_method='gpu_hist', gpu_id=0, predictor='gpu_predictor')
parameters = {'objective':['reg:squarederror'],
              'eval_metric':['rmse'],
              'gamma':[0, 1, 3, 5],
              'min_child_weight': [1, 3, 5, 7],
              'max_depth': [2, 4, 6, 8],
              'n_estimators': [30, 50, 100, 150],
              'learning_rate': [0.1, 0.3, 0.5]
             }

xgb_grid = GridSearchCV(xgb1,
                        parameters,
                        cv=3,
                        n_jobs=-1,
                        verbose=2,
                        scoring='neg_root_mean_squared_error')

xgb_grid.fit(X2, Y2)

end_time = time.time()
print(xgb_grid.best_score_)
print(xgb_grid.best_params_)
print(f'소요시간: {(end_time - start_time)} 초')
# Out:
# Fitting 3 folds for each of 768 candidates, totalling 2304 fits
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[56], line 23
#       7 parameters = {'objective':['reg:squarederror'],
#       8               'eval_metric':['rmse'],
#       9               'gamma':[0, 1, 3, 5],
#    (...)
#      13               'learning_rate': [0.1, 0.3, 0.5]
#      14              }
#      16 xgb_grid = GridSearchCV(xgb1,
#      17                         parameters,
#      18                         cv=3,
#      19                         n_jobs=-1,
#      20                         verbose=2,
#      21                         scoring='neg_root_mean_squared_error')
# ---> 23 xgb_grid.fit(X2, Y2)
#      25 end_time = time.time()
#      26 print(xgb_grid.best_score_)
#
# File ~\anaconda3\envs\tensorflow\lib\site-packages\sklearn\model_selection\_search.py:874, in BaseSearchCV.fit(self, X, y, groups, **fit_params)
#     868     results = self._format_results(
#     869         all_candidate_params, n_splits, all_out, all_more_results
#     870     )
#     872     return results
# --> 874 self._run_search(evaluate_candidates)
#     876 # multimetric is determined here because in the case of a callable
#     877 # self.scoring the return type is only known after calling
#     878 first_test_score = all_out[0]["test_scores"]
#
# File ~\anaconda3\envs\tensorflow\lib\site-packages\sklearn\model_selection\_search.py:1388, in GridSearchCV._run_search(self, evaluate_candidates)
#    1386 def _run_search(self, evaluate_candidates):
#    1387     """Search all candidates in param_grid"""
# -> 1388     evaluate_candidates(ParameterGrid(self.param_grid))
#
# File ~\anaconda3\envs\tensorflow\lib\site-packages\sklearn\model_selection\_search.py:851, in BaseSearchCV.fit.<locals>.evaluate_candidates(candidate_params, cv, more_results)
#     844 elif len(out) != n_candidates * n_splits:
#     845     raise ValueError(
#     846         "cv.split and cv.get_n_splits returned "
#     847         "inconsistent results. Expected {} "
#     848         "splits, got {}".format(n_splits, len(out) // n_candidates)
#     849     )
# --> 851 _warn_or_raise_about_fit_failures(out, self.error_score)
#     853 # For callable self.scoring, the return type is only know after
#     854 # calling. If the return type is a dictionary, the error scores
#     855 # can now be inserted with the correct key. The type checking
#     856 # of out will be done in `_insert_error_scores`.
#     857 if callable(self.scoring):
#
# File ~\anaconda3\envs\tensorflow\lib\site-packages\sklearn\model_selection\_validation.py:367, in _warn_or_raise_about_fit_failures(results, error_score)
#     360 if num_failed_fits == num_fits:
#     361     all_fits_failed_message = (
#     362         f"\nAll the {num_fits} fits failed.\n"
#     363         "It is very likely that your model is misconfigured.\n"
#     364         "You can try to debug the error by setting error_score='raise'.\n\n"
#     365         f"Below are more details about the failures:\n{fit_errors_summary}"
#     366     )
# --> 367     raise ValueError(all_fits_failed_message)
#     369 else:
#     370     some_fits_failed_message = (
#     371         f"\n{num_failed_fits} fits failed out of a total of {num_fits}.\n"
#     372         "The score on these train-test partitions for these parameters"
#    (...)
#     376         f"Below are more details about the failures:\n{fit_errors_summary}"
#     377     )
#
# ValueError:
# All the 2304 fits failed.
# It is very likely that your model is misconfigured.
# You can try to debug the error by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 2304 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\SungHyun\anaconda3\envs\tensorflow\lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\SungHyun\anaconda3\envs\tensorflow\lib\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "C:\Users\SungHyun\anaconda3\envs\tensorflow\lib\site-packages\xgboost\sklearn.py", line 988, in fit
#     train_dmatrix, evals = _wrap_evaluation_matrices(
#   File "C:\Users\SungHyun\anaconda3\envs\tensorflow\lib\site-packages\xgboost\sklearn.py", line 448, in _wrap_evaluation_matrices
#     train_dmatrix = create_dmatrix(
#   File "C:\Users\SungHyun\anaconda3\envs\tensorflow\lib\site-packages\xgboost\sklearn.py", line 903, in _create_dmatrix
#     return QuantileDMatrix(
#   File "C:\Users\SungHyun\anaconda3\envs\tensorflow\lib\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "C:\Users\SungHyun\anaconda3\envs\tensorflow\lib\site-packages\xgboost\core.py", line 1386, in __init__
#     self._init(
#   File "C:\Users\SungHyun\anaconda3\envs\tensorflow\lib\site-packages\xgboost\core.py", line 1445, in _init
#     it.reraise()
#   File "C:\Users\SungHyun\anaconda3\envs\tensorflow\lib\site-packages\xgboost\core.py", line 488, in reraise
#     raise exc  # pylint: disable=raising-bad-type
#   File "C:\Users\SungHyun\anaconda3\envs\tensorflow\lib\site-packages\xgboost\core.py", line 469, in _handle_exception
#     return fn()
#   File "C:\Users\SungHyun\anaconda3\envs\tensorflow\lib\site-packages\xgboost\core.py", line 534, in <lambda>
#     return self._handle_exception(lambda: self.next(input_data), 0)
#   File "C:\Users\SungHyun\anaconda3\envs\tensorflow\lib\site-packages\xgboost\data.py", line 1172, in next
#     input_data(**self.kwargs)
#   File "C:\Users\SungHyun\anaconda3\envs\tensorflow\lib\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "C:\Users\SungHyun\anaconda3\envs\tensorflow\lib\site-packages\xgboost\core.py", line 519, in input_data
#     new, cat_codes, feature_names, feature_types = _proxy_transform(
#   File "C:\Users\SungHyun\anaconda3\envs\tensorflow\lib\site-packages\xgboost\data.py", line 1202, in _proxy_transform
#     arr, feature_names, feature_types = _transform_pandas_df(
#   File "C:\Users\SungHyun\anaconda3\envs\tensorflow\lib\site-packages\xgboost\data.py", line 378, in _transform_pandas_df
#     _invalid_dataframe_dtype(data)
#   File "C:\Users\SungHyun\anaconda3\envs\tensorflow\lib\site-packages\xgboost\data.py", line 270, in _invalid_dataframe_dtype
#     raise ValueError(msg)
# ValueError: DataFrame.dtypes for data must be int, float, bool or category. When categorical type is supplied, The experimental DMatrix parameter`enable_categorical` must be set to `True`.  Invalid columns:week: UInt32

# %%
# # # Various hyper-parameters to tune
# from sklearn.model_selection import GridSearchCV
# import time

# start_time = time.time()
# xgb1 = XGBRegressor(tree_method='gpu_hist', gpu_id=0, predictor='gpu_predictor')
# parameters = {'nthread':[-1], #when use hyperthread, xgboost may become slower
#               'objective':['reg:squarederror'],
#               'eval_metric':['rmse'],
#               'gamma':[10, 20, 50, 100],
#               'learning_rate': [0.05, .1, .15], #so called `eta` value
#               'max_depth': [4, 5, 6],
#               'min_child_weight': [4, 5, 6],
#               'subsample': [0.7],
#               'colsample_bytree': [0.7],
#               'n_estimators': [10, 50, 100, 200]}

# xgb_grid = GridSearchCV(xgb1,
#                         parameters,
#                         cv = 3,
#                         verbose=3)

# xgb_grid.fit(X2, Y2)

# end_time = time.time()

# print(xgb_grid.best_score_)
# print(xgb_grid.best_params_)

# print(f'소요시간: {(end_time - start_time)} 초')
# Out:
# Fitting 3 folds for each of 432 candidates, totalling 1296 fits
# [CV 1/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.05, max_depth=4, min_child_weight=4, n_estimators=10, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 2/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.05, max_depth=4, min_child_weight=4, n_estimators=10, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 3/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.05, max_depth=4, min_child_weight=4, n_estimators=10, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 1/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.05, max_depth=4, min_child_weight=4, n_estimators=50, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 2/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.05, max_depth=4, min_child_weight=4, n_estimators=50, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 3/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.05, max_depth=4, min_child_weight=4, n_estimators=50, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 1/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.05, max_depth=4, min_child_weight=4, n_estimators=100, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 2/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.05, max_depth=4, min_child_weight=4, n_estimators=100, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 3/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.05, max_depth=4, min_child_weight=4, n_estimators=100, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 1/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.05, max_depth=4, min_child_weight=4, n_estimators=200, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 2/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.05, max_depth=4, min_child_weight=4, n_estimators=200, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 3/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.05, max_depth=4, min_child_weight=4, n_estimators=200, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 1/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.05, max_depth=4, min_child_weight=5, n_estimators=10, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 2/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.05, max_depth=4, min_child_weight=5, n_estimators=10, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 3/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.05, max_depth=4, min_child_weight=5, n_estimators=10, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 1/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.05, max_depth=4, min_child_weight=5, n_estimators=50, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 2/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.05, max_depth=4, min_child_weight=5, n_estimators=50, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 3/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.05, max_depth=4, min_child_weight=5, n_estimators=50, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 1/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.05, max_depth=4, min_child_weight=5, n_estimators=100, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 2/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.05, max_depth=4, min_child_weight=5, n_estimators=100, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 3/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.05, max_depth=4, min_child_weight=5, n_estimators=100, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 1/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.05, max_depth=4, min_child_weight=5, n_estimators=200, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 2/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.05, max_depth=4, min_child_weight=5, n_estimators=200, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 3/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.05, max_depth=4, min_child_weight=5, n_estimators=200, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 1/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.05, max_depth=4, min_child_weight=6, n_estimators=10, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 2/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.05, max_depth=4, min_child_weight=6, n_estimators=10, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 3/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.05, max_depth=4, min_child_weight=6, n_estimators=10, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 1/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.05, max_depth=4, min_child_weight=6, n_estimators=50, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 2/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.05, max_depth=4, min_child_weight=6, n_estimators=50, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 3/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.05, max_depth=4, min_child_weight=6, n_estimators=50, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 1/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.05, max_depth=4, min_child_weight=6, n_estimators=100, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 2/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.05, max_depth=4, min_child_weight=6, n_estimators=100, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 3/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.05, max_depth=4, min_child_weight=6, n_estimators=100, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 1/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.05, max_depth=4, min_child_weight=6, n_estimators=200, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 2/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.05, max_depth=4, min_child_weight=6, n_estimators=200, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 3/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.05, max_depth=4, min_child_weight=6, n_estimators=200, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 1/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.05, max_depth=5, min_child_weight=4, n_estimators=10, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 2/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.05, max_depth=5, min_child_weight=4, n_estimators=10, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 3/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.05, max_depth=5, min_child_weight=4, n_estimators=10, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 1/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.05, max_depth=5, min_child_weight=4, n_estimators=50, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 2/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.05, max_depth=5, min_child_weight=4, n_estimators=50, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 3/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.05, max_depth=5, min_child_weight=4, n_estimators=50, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 1/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.05, max_depth=5, min_child_weight=4, n_estimators=100, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 2/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.05, max_depth=5, min_child_weight=4, n_estimators=100, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 3/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.05, max_depth=5, min_child_weight=4, n_estimators=100, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 1/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.05, max_depth=5, min_child_weight=4, n_estimators=200, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 2/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.05, max_depth=5, min_child_weight=4, n_estimators=200, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 3/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.05, max_depth=5, min_child_weight=4, n_estimators=200, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 1/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.05, max_depth=5, min_child_weight=5, n_estimators=10, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 2/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.05, max_depth=5, min_child_weight=5, n_estimators=10, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 3/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.05, max_depth=5, min_child_weight=5, n_estimators=10, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 1/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.05, max_depth=5, min_child_weight=5, n_estimators=50, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 2/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.05, max_depth=5, min_child_weight=5, n_estimators=50, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 3/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.05, max_depth=5, min_child_weight=5, n_estimators=50, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 1/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.05, max_depth=5, min_child_weight=5, n_estimators=100, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 2/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.05, max_depth=5, min_child_weight=5, n_estimators=100, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 3/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.05, max_depth=5, min_child_weight=5, n_estimators=100, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 1/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.05, max_depth=5, min_child_weight=5, n_estimators=200, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 2/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.05, max_depth=5, min_child_weight=5, n_estimators=200, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 3/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.05, max_depth=5, min_child_weight=5, n_estimators=200, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 1/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.05, max_depth=5, min_child_weight=6, n_estimators=10, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 2/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.05, max_depth=5, min_child_weight=6, n_estimators=10, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 3/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.05, max_depth=5, min_child_weight=6, n_estimators=10, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 1/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.05, max_depth=5, min_child_weight=6, n_estimators=50, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 2/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.05, max_depth=5, min_child_weight=6, n_estimators=50, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 3/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.05, max_depth=5, min_child_weight=6, n_estimators=50, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 1/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.05, max_depth=5, min_child_weight=6, n_estimators=100, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 2/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.05, max_depth=5, min_child_weight=6, n_estimators=100, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 3/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.05, max_depth=5, min_child_weight=6, n_estimators=100, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 1/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.05, max_depth=5, min_child_weight=6, n_estimators=200, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 2/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.05, max_depth=5, min_child_weight=6, n_estimators=200, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 3/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.05, max_depth=5, min_child_weight=6, n_estimators=200, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 1/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.05, max_depth=6, min_child_weight=4, n_estimators=10, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 2/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.05, max_depth=6, min_child_weight=4, n_estimators=10, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 3/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.05, max_depth=6, min_child_weight=4, n_estimators=10, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 1/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.05, max_depth=6, min_child_weight=4, n_estimators=50, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 2/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.05, max_depth=6, min_child_weight=4, n_estimators=50, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 3/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.05, max_depth=6, min_child_weight=4, n_estimators=50, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 1/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.05, max_depth=6, min_child_weight=4, n_estimators=100, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 2/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.05, max_depth=6, min_child_weight=4, n_estimators=100, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 3/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.05, max_depth=6, min_child_weight=4, n_estimators=100, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 1/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.05, max_depth=6, min_child_weight=4, n_estimators=200, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 2/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.05, max_depth=6, min_child_weight=4, n_estimators=200, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 3/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.05, max_depth=6, min_child_weight=4, n_estimators=200, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 1/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.05, max_depth=6, min_child_weight=5, n_estimators=10, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 2/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.05, max_depth=6, min_child_weight=5, n_estimators=10, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 3/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.05, max_depth=6, min_child_weight=5, n_estimators=10, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 1/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.05, max_depth=6, min_child_weight=5, n_estimators=50, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 2/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.05, max_depth=6, min_child_weight=5, n_estimators=50, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 3/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.05, max_depth=6, min_child_weight=5, n_estimators=50, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 1/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.05, max_depth=6, min_child_weight=5, n_estimators=100, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 2/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.05, max_depth=6, min_child_weight=5, n_estimators=100, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 3/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.05, max_depth=6, min_child_weight=5, n_estimators=100, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 1/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.05, max_depth=6, min_child_weight=5, n_estimators=200, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 2/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.05, max_depth=6, min_child_weight=5, n_estimators=200, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 3/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.05, max_depth=6, min_child_weight=5, n_estimators=200, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 1/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.05, max_depth=6, min_child_weight=6, n_estimators=10, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 2/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.05, max_depth=6, min_child_weight=6, n_estimators=10, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 3/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.05, max_depth=6, min_child_weight=6, n_estimators=10, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 1/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.05, max_depth=6, min_child_weight=6, n_estimators=50, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 2/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.05, max_depth=6, min_child_weight=6, n_estimators=50, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 3/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.05, max_depth=6, min_child_weight=6, n_estimators=50, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 1/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.05, max_depth=6, min_child_weight=6, n_estimators=100, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 2/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.05, max_depth=6, min_child_weight=6, n_estimators=100, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 3/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.05, max_depth=6, min_child_weight=6, n_estimators=100, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 1/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.05, max_depth=6, min_child_weight=6, n_estimators=200, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 2/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.05, max_depth=6, min_child_weight=6, n_estimators=200, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 3/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.05, max_depth=6, min_child_weight=6, n_estimators=200, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 1/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.1, max_depth=4, min_child_weight=4, n_estimators=10, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 2/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.1, max_depth=4, min_child_weight=4, n_estimators=10, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 3/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.1, max_depth=4, min_child_weight=4, n_estimators=10, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 1/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.1, max_depth=4, min_child_weight=4, n_estimators=50, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 2/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.1, max_depth=4, min_child_weight=4, n_estimators=50, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 3/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.1, max_depth=4, min_child_weight=4, n_estimators=50, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 1/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.1, max_depth=4, min_child_weight=4, n_estimators=100, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 2/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.1, max_depth=4, min_child_weight=4, n_estimators=100, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 3/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.1, max_depth=4, min_child_weight=4, n_estimators=100, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 1/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.1, max_depth=4, min_child_weight=4, n_estimators=200, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 2/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.1, max_depth=4, min_child_weight=4, n_estimators=200, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 3/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.1, max_depth=4, min_child_weight=4, n_estimators=200, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 1/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.1, max_depth=4, min_child_weight=5, n_estimators=10, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 2/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.1, max_depth=4, min_child_weight=5, n_estimators=10, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 3/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.1, max_depth=4, min_child_weight=5, n_estimators=10, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 1/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.1, max_depth=4, min_child_weight=5, n_estimators=50, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 2/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.1, max_depth=4, min_child_weight=5, n_estimators=50, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 3/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.1, max_depth=4, min_child_weight=5, n_estimators=50, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 1/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.1, max_depth=4, min_child_weight=5, n_estimators=100, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 2/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.1, max_depth=4, min_child_weight=5, n_estimators=100, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 3/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.1, max_depth=4, min_child_weight=5, n_estimators=100, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 1/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.1, max_depth=4, min_child_weight=5, n_estimators=200, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 2/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.1, max_depth=4, min_child_weight=5, n_estimators=200, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 3/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.1, max_depth=4, min_child_weight=5, n_estimators=200, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 1/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.1, max_depth=4, min_child_weight=6, n_estimators=10, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 2/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.1, max_depth=4, min_child_weight=6, n_estimators=10, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 3/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.1, max_depth=4, min_child_weight=6, n_estimators=10, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 1/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.1, max_depth=4, min_child_weight=6, n_estimators=50, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 2/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.1, max_depth=4, min_child_weight=6, n_estimators=50, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 3/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.1, max_depth=4, min_child_weight=6, n_estimators=50, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 1/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.1, max_depth=4, min_child_weight=6, n_estimators=100, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 2/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.1, max_depth=4, min_child_weight=6, n_estimators=100, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 3/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.1, max_depth=4, min_child_weight=6, n_estimators=100, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 1/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.1, max_depth=4, min_child_weight=6, n_estimators=200, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 2/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.1, max_depth=4, min_child_weight=6, n_estimators=200, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 3/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.1, max_depth=4, min_child_weight=6, n_estimators=200, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 1/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.1, max_depth=5, min_child_weight=4, n_estimators=10, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 2/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.1, max_depth=5, min_child_weight=4, n_estimators=10, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 3/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.1, max_depth=5, min_child_weight=4, n_estimators=10, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 1/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.1, max_depth=5, min_child_weight=4, n_estimators=50, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 2/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.1, max_depth=5, min_child_weight=4, n_estimators=50, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 3/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.1, max_depth=5, min_child_weight=4, n_estimators=50, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 1/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.1, max_depth=5, min_child_weight=4, n_estimators=100, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 2/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.1, max_depth=5, min_child_weight=4, n_estimators=100, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 3/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.1, max_depth=5, min_child_weight=4, n_estimators=100, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 1/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.1, max_depth=5, min_child_weight=4, n_estimators=200, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 2/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.1, max_depth=5, min_child_weight=4, n_estimators=200, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 3/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.1, max_depth=5, min_child_weight=4, n_estimators=200, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 1/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.1, max_depth=5, min_child_weight=5, n_estimators=10, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 2/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.1, max_depth=5, min_child_weight=5, n_estimators=10, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 3/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.1, max_depth=5, min_child_weight=5, n_estimators=10, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 1/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.1, max_depth=5, min_child_weight=5, n_estimators=50, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 2/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.1, max_depth=5, min_child_weight=5, n_estimators=50, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 3/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.1, max_depth=5, min_child_weight=5, n_estimators=50, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 1/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.1, max_depth=5, min_child_weight=5, n_estimators=100, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 2/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.1, max_depth=5, min_child_weight=5, n_estimators=100, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 3/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.1, max_depth=5, min_child_weight=5, n_estimators=100, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 1/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.1, max_depth=5, min_child_weight=5, n_estimators=200, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 2/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.1, max_depth=5, min_child_weight=5, n_estimators=200, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 3/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.1, max_depth=5, min_child_weight=5, n_estimators=200, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 1/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.1, max_depth=5, min_child_weight=6, n_estimators=10, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 2/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.1, max_depth=5, min_child_weight=6, n_estimators=10, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 3/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.1, max_depth=5, min_child_weight=6, n_estimators=10, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 1/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.1, max_depth=5, min_child_weight=6, n_estimators=50, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 2/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.1, max_depth=5, min_child_weight=6, n_estimators=50, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 3/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.1, max_depth=5, min_child_weight=6, n_estimators=50, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 1/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.1, max_depth=5, min_child_weight=6, n_estimators=100, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 2/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.1, max_depth=5, min_child_weight=6, n_estimators=100, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 3/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.1, max_depth=5, min_child_weight=6, n_estimators=100, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 1/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.1, max_depth=5, min_child_weight=6, n_estimators=200, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 2/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.1, max_depth=5, min_child_weight=6, n_estimators=200, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 3/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.1, max_depth=5, min_child_weight=6, n_estimators=200, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 1/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.1, max_depth=6, min_child_weight=4, n_estimators=10, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 2/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.1, max_depth=6, min_child_weight=4, n_estimators=10, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 3/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.1, max_depth=6, min_child_weight=4, n_estimators=10, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 1/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.1, max_depth=6, min_child_weight=4, n_estimators=50, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 2/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.1, max_depth=6, min_child_weight=4, n_estimators=50, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 3/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.1, max_depth=6, min_child_weight=4, n_estimators=50, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 1/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.1, max_depth=6, min_child_weight=4, n_estimators=100, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 2/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.1, max_depth=6, min_child_weight=4, n_estimators=100, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 3/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.1, max_depth=6, min_child_weight=4, n_estimators=100, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 1/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.1, max_depth=6, min_child_weight=4, n_estimators=200, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 2/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.1, max_depth=6, min_child_weight=4, n_estimators=200, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 3/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.1, max_depth=6, min_child_weight=4, n_estimators=200, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 1/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.1, max_depth=6, min_child_weight=5, n_estimators=10, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 2/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.1, max_depth=6, min_child_weight=5, n_estimators=10, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 3/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.1, max_depth=6, min_child_weight=5, n_estimators=10, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 1/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.1, max_depth=6, min_child_weight=5, n_estimators=50, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 2/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.1, max_depth=6, min_child_weight=5, n_estimators=50, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 3/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.1, max_depth=6, min_child_weight=5, n_estimators=50, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 1/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.1, max_depth=6, min_child_weight=5, n_estimators=100, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 2/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.1, max_depth=6, min_child_weight=5, n_estimators=100, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 3/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.1, max_depth=6, min_child_weight=5, n_estimators=100, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 1/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.1, max_depth=6, min_child_weight=5, n_estimators=200, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 2/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.1, max_depth=6, min_child_weight=5, n_estimators=200, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 3/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.1, max_depth=6, min_child_weight=5, n_estimators=200, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 1/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.1, max_depth=6, min_child_weight=6, n_estimators=10, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 2/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.1, max_depth=6, min_child_weight=6, n_estimators=10, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 3/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.1, max_depth=6, min_child_weight=6, n_estimators=10, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 1/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.1, max_depth=6, min_child_weight=6, n_estimators=50, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 2/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.1, max_depth=6, min_child_weight=6, n_estimators=50, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 3/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.1, max_depth=6, min_child_weight=6, n_estimators=50, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 1/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.1, max_depth=6, min_child_weight=6, n_estimators=100, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 2/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.1, max_depth=6, min_child_weight=6, n_estimators=100, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 3/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.1, max_depth=6, min_child_weight=6, n_estimators=100, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 1/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.1, max_depth=6, min_child_weight=6, n_estimators=200, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 2/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.1, max_depth=6, min_child_weight=6, n_estimators=200, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 3/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.1, max_depth=6, min_child_weight=6, n_estimators=200, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 1/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.15, max_depth=4, min_child_weight=4, n_estimators=10, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 2/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.15, max_depth=4, min_child_weight=4, n_estimators=10, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 3/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=10, learning_rate=0.15, max_depth=4, min_child_weight=4, n_estimators=10, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# ...
# [CV 3/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=100, learning_rate=0.15, max_depth=5, min_child_weight=6, n_estimators=50, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 1/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=100, learning_rate=0.15, max_depth=5, min_child_weight=6, n_estimators=100, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 2/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=100, learning_rate=0.15, max_depth=5, min_child_weight=6, n_estimators=100, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 3/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=100, learning_rate=0.15, max_depth=5, min_child_weight=6, n_estimators=100, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 1/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=100, learning_rate=0.15, max_depth=5, min_child_weight=6, n_estimators=200, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 2/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=100, learning_rate=0.15, max_depth=5, min_child_weight=6, n_estimators=200, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 3/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=100, learning_rate=0.15, max_depth=5, min_child_weight=6, n_estimators=200, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 1/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=100, learning_rate=0.15, max_depth=6, min_child_weight=4, n_estimators=10, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 2/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=100, learning_rate=0.15, max_depth=6, min_child_weight=4, n_estimators=10, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 3/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=100, learning_rate=0.15, max_depth=6, min_child_weight=4, n_estimators=10, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 1/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=100, learning_rate=0.15, max_depth=6, min_child_weight=4, n_estimators=50, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 2/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=100, learning_rate=0.15, max_depth=6, min_child_weight=4, n_estimators=50, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 3/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=100, learning_rate=0.15, max_depth=6, min_child_weight=4, n_estimators=50, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 1/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=100, learning_rate=0.15, max_depth=6, min_child_weight=4, n_estimators=100, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 2/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=100, learning_rate=0.15, max_depth=6, min_child_weight=4, n_estimators=100, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 3/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=100, learning_rate=0.15, max_depth=6, min_child_weight=4, n_estimators=100, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 1/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=100, learning_rate=0.15, max_depth=6, min_child_weight=4, n_estimators=200, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 2/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=100, learning_rate=0.15, max_depth=6, min_child_weight=4, n_estimators=200, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 3/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=100, learning_rate=0.15, max_depth=6, min_child_weight=4, n_estimators=200, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 1/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=100, learning_rate=0.15, max_depth=6, min_child_weight=5, n_estimators=10, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 2/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=100, learning_rate=0.15, max_depth=6, min_child_weight=5, n_estimators=10, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 3/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=100, learning_rate=0.15, max_depth=6, min_child_weight=5, n_estimators=10, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 1/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=100, learning_rate=0.15, max_depth=6, min_child_weight=5, n_estimators=50, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 2/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=100, learning_rate=0.15, max_depth=6, min_child_weight=5, n_estimators=50, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 3/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=100, learning_rate=0.15, max_depth=6, min_child_weight=5, n_estimators=50, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 1/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=100, learning_rate=0.15, max_depth=6, min_child_weight=5, n_estimators=100, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 2/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=100, learning_rate=0.15, max_depth=6, min_child_weight=5, n_estimators=100, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 3/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=100, learning_rate=0.15, max_depth=6, min_child_weight=5, n_estimators=100, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 1/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=100, learning_rate=0.15, max_depth=6, min_child_weight=5, n_estimators=200, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 2/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=100, learning_rate=0.15, max_depth=6, min_child_weight=5, n_estimators=200, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 3/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=100, learning_rate=0.15, max_depth=6, min_child_weight=5, n_estimators=200, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 1/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=100, learning_rate=0.15, max_depth=6, min_child_weight=6, n_estimators=10, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 2/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=100, learning_rate=0.15, max_depth=6, min_child_weight=6, n_estimators=10, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 3/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=100, learning_rate=0.15, max_depth=6, min_child_weight=6, n_estimators=10, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 1/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=100, learning_rate=0.15, max_depth=6, min_child_weight=6, n_estimators=50, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 2/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=100, learning_rate=0.15, max_depth=6, min_child_weight=6, n_estimators=50, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 3/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=100, learning_rate=0.15, max_depth=6, min_child_weight=6, n_estimators=50, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 1/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=100, learning_rate=0.15, max_depth=6, min_child_weight=6, n_estimators=100, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 2/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=100, learning_rate=0.15, max_depth=6, min_child_weight=6, n_estimators=100, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 3/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=100, learning_rate=0.15, max_depth=6, min_child_weight=6, n_estimators=100, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 1/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=100, learning_rate=0.15, max_depth=6, min_child_weight=6, n_estimators=200, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 2/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=100, learning_rate=0.15, max_depth=6, min_child_weight=6, n_estimators=200, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# [CV 3/3] END colsample_bytree=0.7, eval_metric=rmse, gamma=100, learning_rate=0.15, max_depth=6, min_child_weight=6, n_estimators=200, nthread=-1, objective=reg:squarederror, subsample=0.7;, score=nan total time=   0.0s
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[58], line 23
#       7 parameters = {'nthread':[-1], #when use hyperthread, xgboost may become slower
#       8               'objective':['reg:squarederror'],
#       9               'eval_metric':['rmse'],
#    (...)
#      15               'colsample_bytree': [0.7],
#      16               'n_estimators': [10, 50, 100, 200]}
#      18 xgb_grid = GridSearchCV(xgb1,
#      19                         parameters,
#      20                         cv = 3,
#      21                         verbose=3)
# ---> 23 xgb_grid.fit(X2, Y2)
#      25 end_time = time.time()
#      27 print(xgb_grid.best_score_)
#
# File ~\anaconda3\envs\tensorflow\lib\site-packages\sklearn\model_selection\_search.py:874, in BaseSearchCV.fit(self, X, y, groups, **fit_params)
#     868     results = self._format_results(
#     869         all_candidate_params, n_splits, all_out, all_more_results
#     870     )
#     872     return results
# --> 874 self._run_search(evaluate_candidates)
#     876 # multimetric is determined here because in the case of a callable
#     877 # self.scoring the return type is only known after calling
#     878 first_test_score = all_out[0]["test_scores"]
#
# File ~\anaconda3\envs\tensorflow\lib\site-packages\sklearn\model_selection\_search.py:1388, in GridSearchCV._run_search(self, evaluate_candidates)
#    1386 def _run_search(self, evaluate_candidates):
#    1387     """Search all candidates in param_grid"""
# -> 1388     evaluate_candidates(ParameterGrid(self.param_grid))
#
# File ~\anaconda3\envs\tensorflow\lib\site-packages\sklearn\model_selection\_search.py:851, in BaseSearchCV.fit.<locals>.evaluate_candidates(candidate_params, cv, more_results)
#     844 elif len(out) != n_candidates * n_splits:
#     845     raise ValueError(
#     846         "cv.split and cv.get_n_splits returned "
#     847         "inconsistent results. Expected {} "
#     848         "splits, got {}".format(n_splits, len(out) // n_candidates)
#     849     )
# --> 851 _warn_or_raise_about_fit_failures(out, self.error_score)
#     853 # For callable self.scoring, the return type is only know after
#     854 # calling. If the return type is a dictionary, the error scores
#     855 # can now be inserted with the correct key. The type checking
#     856 # of out will be done in `_insert_error_scores`.
#     857 if callable(self.scoring):
#
# File ~\anaconda3\envs\tensorflow\lib\site-packages\sklearn\model_selection\_validation.py:367, in _warn_or_raise_about_fit_failures(results, error_score)
#     360 if num_failed_fits == num_fits:
#     361     all_fits_failed_message = (
#     362         f"\nAll the {num_fits} fits failed.\n"
#     363         "It is very likely that your model is misconfigured.\n"
#     364         "You can try to debug the error by setting error_score='raise'.\n\n"
#     365         f"Below are more details about the failures:\n{fit_errors_summary}"
#     366     )
# --> 367     raise ValueError(all_fits_failed_message)
#     369 else:
#     370     some_fits_failed_message = (
#     371         f"\n{num_failed_fits} fits failed out of a total of {num_fits}.\n"
#     372         "The score on these train-test partitions for these parameters"
#    (...)
#     376         f"Below are more details about the failures:\n{fit_errors_summary}"
#     377     )
#
# ValueError:
# All the 1296 fits failed.
# It is very likely that your model is misconfigured.
# You can try to debug the error by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 1296 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\SungHyun\anaconda3\envs\tensorflow\lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\SungHyun\anaconda3\envs\tensorflow\lib\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "C:\Users\SungHyun\anaconda3\envs\tensorflow\lib\site-packages\xgboost\sklearn.py", line 988, in fit
#     train_dmatrix, evals = _wrap_evaluation_matrices(
#   File "C:\Users\SungHyun\anaconda3\envs\tensorflow\lib\site-packages\xgboost\sklearn.py", line 448, in _wrap_evaluation_matrices
#     train_dmatrix = create_dmatrix(
#   File "C:\Users\SungHyun\anaconda3\envs\tensorflow\lib\site-packages\xgboost\sklearn.py", line 903, in _create_dmatrix
#     return QuantileDMatrix(
#   File "C:\Users\SungHyun\anaconda3\envs\tensorflow\lib\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "C:\Users\SungHyun\anaconda3\envs\tensorflow\lib\site-packages\xgboost\core.py", line 1386, in __init__
#     self._init(
#   File "C:\Users\SungHyun\anaconda3\envs\tensorflow\lib\site-packages\xgboost\core.py", line 1445, in _init
#     it.reraise()
#   File "C:\Users\SungHyun\anaconda3\envs\tensorflow\lib\site-packages\xgboost\core.py", line 488, in reraise
#     raise exc  # pylint: disable=raising-bad-type
#   File "C:\Users\SungHyun\anaconda3\envs\tensorflow\lib\site-packages\xgboost\core.py", line 469, in _handle_exception
#     return fn()
#   File "C:\Users\SungHyun\anaconda3\envs\tensorflow\lib\site-packages\xgboost\core.py", line 534, in <lambda>
#     return self._handle_exception(lambda: self.next(input_data), 0)
#   File "C:\Users\SungHyun\anaconda3\envs\tensorflow\lib\site-packages\xgboost\data.py", line 1172, in next
#     input_data(**self.kwargs)
#   File "C:\Users\SungHyun\anaconda3\envs\tensorflow\lib\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "C:\Users\SungHyun\anaconda3\envs\tensorflow\lib\site-packages\xgboost\core.py", line 519, in input_data
#     new, cat_codes, feature_names, feature_types = _proxy_transform(
#   File "C:\Users\SungHyun\anaconda3\envs\tensorflow\lib\site-packages\xgboost\data.py", line 1202, in _proxy_transform
#     arr, feature_names, feature_types = _transform_pandas_df(
#   File "C:\Users\SungHyun\anaconda3\envs\tensorflow\lib\site-packages\xgboost\data.py", line 378, in _transform_pandas_df
#     _invalid_dataframe_dtype(data)
#   File "C:\Users\SungHyun\anaconda3\envs\tensorflow\lib\site-packages\xgboost\data.py", line 270, in _invalid_dataframe_dtype
#     raise ValueError(msg)
# ValueError: DataFrame.dtypes for data must be int, float, bool or category. When categorical type is supplied, The experimental DMatrix parameter`enable_categorical` must be set to `True`.  Invalid columns:week: UInt32

# %%
# Fitting 3 folds for each of 768 candidates, totalling 2304 fits
# -38.585284593854745
# {'eval_metric': 'rmse', 'gamma': 0, 'learning_rate': 0.1, 'max_depth': 6, 'min_child_weight': 5, 'n_estimators': 50, 'objective': 'reg:squarederror'}
# 소요시간: 506.40148639678955 초

# %%
#{'colsample_bytree': 0.7, 'eval_metric': 'rmse', 'gamma': 50, 'learning_rate': 0.03, 'max_depth': 5, 'min_child_weight': 4, 'n_estimators': 100, 'nthread': 4, 'objective': 'reg:linear', 'subsample': 0.7}
#{'colsample_bytree': 0.7, 'eval_metric': 'rmse', 'gamma': 10, 'learning_rate': 0.05, 'max_depth': 5, 'min_child_weight': 4, 'n_estimators': 100, 'nthread': 4, 'objective': 'reg:squarederror', 'subsample': 0.7}
#{'colsample_bytree': 0.7, 'eval_metric': 'rmse', 'gamma': 20, 'learning_rate': 0.05, 'max_depth': 5, 'min_child_weight': 5, 'n_estimators': 100, 'nthread': 4, 'objective': 'reg:squarederror', 'subsample': 0.7}
#{'eval_metric': 'rmse', 'gamma': 0, 'learning_rate': 0.1, 'max_depth': 4, 'min_child_weight': 5, 'n_estimators': 50, 'objective': 'reg:squarederror'}
# {'eval_metric': 'rmse', 'gamma': 0, 'learning_rate': 0.1, 'max_depth': 6, 'min_child_weight': 5, 'n_estimators': 50, 'objective': 'reg:squarederror'}

# %%
from sklearn.metrics import mean_squared_error
from math import sqrt
def calRmse(p, a):
    rmse = sqrt(mean_squared_error(p, a))
    return rmse

# %%
best_params = {'eval_metric': 'rmse', 'gamma': 1, 'learning_rate': 0.2, 'max_depth': 7, 'min_child_weight': 4, 'n_estimators': 150, 'objective': 'reg:squarederror'}
# best_params = xgb_grid.best_params_

xgb = XGBRegressor(**best_params, tree_method='gpu_hist', gpu_id=0, predictor='gpu_predictor')

xgb.fit(X_train, Y_train)

ypred1 = xgb.predict(X_test)

print(calRmse(ypred1, y_test))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[60], line 6
#       2 # best_params = xgb_grid.best_params_
#       4 xgb = XGBRegressor(**best_params, tree_method='gpu_hist', gpu_id=0, predictor='gpu_predictor')
# ----> 6 xgb.fit(X_train, Y_train)
#       8 ypred1 = xgb.predict(X_test)
#      10 print(calRmse(ypred1, y_test))
#
# File ~\anaconda3\envs\tensorflow\lib\site-packages\xgboost\core.py:620, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     618 for k, arg in zip(sig.parameters, args):
#     619     kwargs[k] = arg
# --> 620 return func(**kwargs)
#
# File ~\anaconda3\envs\tensorflow\lib\site-packages\xgboost\sklearn.py:988, in XGBModel.fit(self, X, y, sample_weight, base_margin, eval_set, eval_metric, early_stopping_rounds, verbose, xgb_model, sample_weight_eval_set, base_margin_eval_set, feature_weights, callbacks)
#     986 with config_context(verbosity=self.verbosity):
#     987     evals_result: TrainingCallback.EvalsLog = {}
# --> 988     train_dmatrix, evals = _wrap_evaluation_matrices(
#     989         missing=self.missing,
#     990         X=X,
#     991         y=y,
#     992         group=None,
#     993         qid=None,
#     994         sample_weight=sample_weight,
#     995         base_margin=base_margin,
#     996         feature_weights=feature_weights,
#     997         eval_set=eval_set,
#     998         sample_weight_eval_set=sample_weight_eval_set,
#     999         base_margin_eval_set=base_margin_eval_set,
#    1000         eval_group=None,
#    1001         eval_qid=None,
#    1002         create_dmatrix=self._create_dmatrix,
#    1003         enable_categorical=self.enable_categorical,
#    1004         feature_types=self.feature_types,
#    1005     )
#    1006     params = self.get_xgb_params()
#    1008     if callable(self.objective):
#
# File ~\anaconda3\envs\tensorflow\lib\site-packages\xgboost\sklearn.py:448, in _wrap_evaluation_matrices(missing, X, y, group, qid, sample_weight, base_margin, feature_weights, eval_set, sample_weight_eval_set, base_margin_eval_set, eval_group, eval_qid, create_dmatrix, enable_categorical, feature_types)
#     428 def _wrap_evaluation_matrices(
#     429     missing: float,
#     430     X: Any,
#    (...)
#     444     feature_types: Optional[FeatureTypes],
#     445 ) -> Tuple[Any, List[Tuple[Any, str]]]:
#     446     """Convert array_like evaluation matrices into DMatrix.  Perform validation on the
#     447     way."""
# --> 448     train_dmatrix = create_dmatrix(
#     449         data=X,
#     450         label=y,
#     451         group=group,
#     452         qid=qid,
#     453         weight=sample_weight,
#     454         base_margin=base_margin,
#     455         feature_weights=feature_weights,
#     456         missing=missing,
#     457         enable_categorical=enable_categorical,
#     458         feature_types=feature_types,
#     459         ref=None,
#     460     )
#     462     n_validation = 0 if eval_set is None else len(eval_set)
#     464     def validate_or_none(meta: Optional[Sequence], name: str) -> Sequence:
#
# File ~\anaconda3\envs\tensorflow\lib\site-packages\xgboost\sklearn.py:903, in XGBModel._create_dmatrix(self, ref, **kwargs)
#     901 if self.tree_method in ("hist", "gpu_hist"):
#     902     try:
# --> 903         return QuantileDMatrix(
#     904             **kwargs, ref=ref, nthread=self.n_jobs, max_bin=self.max_bin
#     905         )
#     906     except TypeError:  # `QuantileDMatrix` supports lesser types than DMatrix
#     907         pass
#
# File ~\anaconda3\envs\tensorflow\lib\site-packages\xgboost\core.py:620, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     618 for k, arg in zip(sig.parameters, args):
#     619     kwargs[k] = arg
# --> 620 return func(**kwargs)
#
# File ~\anaconda3\envs\tensorflow\lib\site-packages\xgboost\core.py:1386, in QuantileDMatrix.__init__(self, data, label, weight, base_margin, missing, silent, feature_names, feature_types, nthread, max_bin, ref, group, qid, label_lower_bound, label_upper_bound, feature_weights, enable_categorical)
#    1366     if any(
#    1367         info is not None
#    1368         for info in (
#    (...)
#    1379         )
#    1380     ):
#    1381         raise ValueError(
#    1382             "If data iterator is used as input, data like label should be "
#    1383             "specified as batch argument."
#    1384         )
# -> 1386 self._init(
#    1387     data,
#    1388     ref=ref,
#    1389     label=label,
#    1390     weight=weight,
#    1391     base_margin=base_margin,
#    1392     group=group,
#    1393     qid=qid,
#    1394     label_lower_bound=label_lower_bound,
#    1395     label_upper_bound=label_upper_bound,
#    1396     feature_weights=feature_weights,
#    1397     feature_names=feature_names,
#    1398     feature_types=feature_types,
#    1399     enable_categorical=enable_categorical,
#    1400 )
#
# File ~\anaconda3\envs\tensorflow\lib\site-packages\xgboost\core.py:1445, in QuantileDMatrix._init(self, data, ref, enable_categorical, **meta)
#    1433 config = make_jcargs(
#    1434     nthread=self.nthread, missing=self.missing, max_bin=self.max_bin
#    1435 )
#    1436 ret = _LIB.XGQuantileDMatrixCreateFromCallback(
#    1437     None,
#    1438     it.proxy.handle,
#    (...)
#    1443     ctypes.byref(handle),
#    1444 )
# -> 1445 it.reraise()
#    1446 # delay check_call to throw intermediate exception first
#    1447 _check_call(ret)
#
# File ~\anaconda3\envs\tensorflow\lib\site-packages\xgboost\core.py:488, in DataIter.reraise(self)
#     486 exc = self._exception
#     487 self._exception = None
# --> 488 raise exc
#
# File ~\anaconda3\envs\tensorflow\lib\site-packages\xgboost\core.py:469, in DataIter._handle_exception(self, fn, dft_ret)
#     466     return dft_ret
#     468 try:
# --> 469     return fn()
#     470 except Exception as e:  # pylint: disable=broad-except
#     471     # Defer the exception in order to return 0 and stop the iteration.
#     472     # Exception inside a ctype callback function has no effect except
#     473     # for printing to stderr (doesn't stop the execution).
#     474     tb = sys.exc_info()[2]
#
# File ~\anaconda3\envs\tensorflow\lib\site-packages\xgboost\core.py:534, in DataIter._next_wrapper.<locals>.<lambda>()
#     528     self.proxy.set_info(
#     529         feature_names=feature_names,
#     530         feature_types=feature_types,
#     531         **kwargs,
#     532     )
#     533 # pylint: disable=not-callable
# --> 534 return self._handle_exception(lambda: self.next(input_data), 0)
#
# File ~\anaconda3\envs\tensorflow\lib\site-packages\xgboost\data.py:1172, in SingleBatchInternalIter.next(self, input_data)
#    1170     return 0
#    1171 self.it += 1
# -> 1172 input_data(**self.kwargs)
#    1173 return 1
#
# File ~\anaconda3\envs\tensorflow\lib\site-packages\xgboost\core.py:620, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     618 for k, arg in zip(sig.parameters, args):
#     619     kwargs[k] = arg
# --> 620 return func(**kwargs)
#
# File ~\anaconda3\envs\tensorflow\lib\site-packages\xgboost\core.py:519, in DataIter._next_wrapper.<locals>.input_data(data, feature_names, feature_types, **kwargs)
#     516 from .data import dispatch_proxy_set_data
#     517 from .data import _proxy_transform
# --> 519 new, cat_codes, feature_names, feature_types = _proxy_transform(
#     520     data,
#     521     feature_names,
#     522     feature_types,
#     523     self._enable_categorical,
#     524 )
#     525 # Stage the data, meta info are copied inside C++ MetaInfo.
#     526 self._temporary_data = (new, cat_codes)
#
# File ~\anaconda3\envs\tensorflow\lib\site-packages\xgboost\data.py:1202, in _proxy_transform(data, feature_names, feature_types, enable_categorical)
#    1200     return data, None, feature_names, feature_types
#    1201 if _is_pandas_df(data):
# -> 1202     arr, feature_names, feature_types = _transform_pandas_df(
#    1203         data, enable_categorical, feature_names, feature_types
#    1204     )
#    1205     return arr, None, feature_names, feature_types
#    1206 raise TypeError("Value type is not supported for data iterator:" + str(type(data)))
#
# File ~\anaconda3\envs\tensorflow\lib\site-packages\xgboost\data.py:378, in _transform_pandas_df(data, enable_categorical, feature_names, feature_types, meta, meta_type)
#     366 from pandas.api.types import (
#     367     is_sparse,
#     368     is_categorical_dtype,
#     369 )
#     371 if not all(
#     372     dtype.name in _pandas_dtype_mapper
#     373     or is_sparse(dtype)
#    (...)
#     376     for dtype in data.dtypes
#     377 ):
# --> 378     _invalid_dataframe_dtype(data)
#     380 feature_names, feature_types = _pandas_feature_info(
#     381     data, meta, feature_names, feature_types, enable_categorical
#     382 )
#     384 transformed = _pandas_cat_null(data)
#
# File ~\anaconda3\envs\tensorflow\lib\site-packages\xgboost\data.py:270, in _invalid_dataframe_dtype(data)
#     268 type_err = "DataFrame.dtypes for data must be int, float, bool or category."
#     269 msg = f"""{type_err} {_ENABLE_CAT_ERR} {err}"""
# --> 270 raise ValueError(msg)
#
# ValueError: DataFrame.dtypes for data must be int, float, bool or category. When categorical type is supplied, The experimental DMatrix parameter`enable_categorical` must be set to `True`.  Invalid columns:week: UInt32

# %%
xgb2 = XGBRegressor(tree_method='gpu_hist', gpu_id=0, predictor='gpu_predictor')

xgb2.fit(X_train, Y_train)

ypred2 = xgb2.predict(X_test)

print(calRmse(ypred2, y_test))

# %%
xgb3 = XGBRegressor(tree_method='gpu_hist', gpu_id=0, predictor='gpu_predictor',
                    gamma = 3, min_child_weight = 4, max_depth = 7, n_estimators = 150)

xgb3.fit(X_train, Y_train)

ypred3 = xgb3.predict(X_test)

print(calRmse(ypred3, y_test))

# %%
x1 = range(len(ypred1))

plt.plot(x1, y_test)
plt.plot(x1, ypred1)
plt.legend(['real', 'yield'])
plt.show()

plt.plot(x1, ypred1)
plt.plot(x1, ypred2)
plt.legend(['mine', 'default'])
plt.show()

# %%
# # tempg = xgb_grid_best_params_
# train = pd.read_excel('Train_dataset.xlsx')

# train['Time'] = pd.to_datetime(train['Time'], format='%Y%m%d_%H')

# train = pd.merge(train, weather, on='Time', how='inner')


# ## 변수들을 영문명으로 변경
# cols = ['date_time', 'power', 'temp', 'hum', 'wind', 'sun', 'prec']
# train.columns = cols

# # 시간 관련 변수들 생성
# date = pd.to_datetime(train.date_time)
# train['hour'] = date.dt.hour
# train['day'] = date.dt.weekday
# train['month'] = date.dt.month
# train['week'] = date.dt.weekofyear

# # hour_mean = train.groupby(train['hour'])['power'].mean()
# # train['hour_mean'] = train['hour'].map(hour_mean)

# # day_mean = train.groupby(train['day'])['power'].mean()
# # train['day_mean'] = train['day'].map(day_mean)

# # week_mean = train.groupby(train['week'])['power'].mean()
# # train['week_mean'] = train['week'].map(week_mean)

# # month_mean = train.groupby(train['month'])['power'].mean()
# # train['month_mean'] = train['month'].map(month_mean)

# ### 공휴일 변수 추가
# train['holiday'] = train.apply(lambda x : 0 if x['day']<5 else 1, axis = 1)

# ## https://dacon.io/competitions/official/235680/codeshare/2366?page=1&dtype=recent
# train['sin_time'] = np.sin(2*np.pi*train.hour/24)
# train['cos_time'] = np.cos(2*np.pi*train.hour/24)

# ## https://dacon.io/competitions/official/235736/codeshare/2743?page=1&dtype=recent
# train['THI'] = 9/5*train['temp'] - 0.55*(1-train['hum']/100)*(9/5*train['hum']-26)+32

# def CDH(xs):
#     ys = []
#     for i in range(len(xs)):
#         if i < 11:
#             ys.append(np.sum(xs[:(i+1)]-26))
#         else:
#             ys.append(np.sum(xs[(i-11):(i+1)]-26))
#     return np.array(ys)

# train.drop(['hour','date_time'], axis = 1, inplace = True)
# train.head()

# %%
# features = ['temp', 'hum', 'wind', 'sun', 'prec', 'day', 'month', 'week', 'hour_mean', 'day_mean', 
#             'week_mean', 'month_mean', 'holiday', 'sin_time', 'cos_time', 'THI']

X = train[features]
y = train['power']

xgb = XGBRegressor(**best_params, tree_method='gpu_hist', gpu_id=0, predictor='gpu_predictor')
# xgb = XGBRegressor(tree_method='gpu_hist', gpu_id=0, predictor='gpu_predictor')

xgb.fit(X,y)

# %%
# answer.drop(['date_time'], axis = 1, inplace = True)
answer.info()

# %%
y_pred = xgb.predict(answer)

# %%
# y_pred = pd.DataFrame(y_pred)
# y_pred.columns = ["Power"]
# display(y_pred)

# columns_to_inverse_scale = [col for col in answer.columns]
# df_to_inverse_scale = answer[columns_to_inverse_scale]

# display(df_to_inverse_scale)

# # Inverse transform the scaled data
# inverse_scaled_data = scaler.inverse_transform(df_to_inverse_scale)

# # Create a new DataFrame with the inverse scaled data
# inverse_scaled_df = pd.DataFrame(answer, columns=columns_to_inverse_scale)

# # Add the excluded columns back to the inverse scaled DataFrame
# # inverse_scaled_df[exclude_columns] = answer[exclude_columns]

# display(inverse_scaled_df)

# %%
y_pred = pd.DataFrame(y_pred)
y_pred.columns = ["Power"]
display(y_pred)
display(answer)
result = pd.concat([answer, y_pred], axis=1)
display(result)

# %%
# exclude_columns = ['Power']
# columns_to_inverse_scale = [col for col in result.columns if col not in exclude_columns]
# df_to_inverse_scale = result[columns_to_inverse_scale]

# print(df_to_inverse_scale)

# # Inverse transform the scaled data
# inverse_scaled_data = scaler.inverse_transform(df_to_inverse_scale)

# # Create a new DataFrame with the inverse scaled data
# inverse_scaled_df = pd.DataFrame(result, columns=columns_to_inverse_scale)

# # Add the excluded columns back to the inverse scaled DataFrame
# inverse_scaled_df[exclude_columns] = result[exclude_columns]

# display(inverse_scaled_df)

# %%
real_answer = pd.read_excel('Answer_sheet.xlsx')
real_answer['Time'] = pd.to_datetime(real_answer['Time'], format='%Y%m%d_%H')
real_answer = pd.concat([real_answer, result['Power']], axis=1)
display(real_answer)
real_answer.loc[real_answer['Time'].isin(zero_time), 'Power'] = 0

# %%
#real_answer.to_excel('predict_18011668_변성현_6주차.xlsx', index=False)

# %%
# real_answer.to_excel('tmp3.xlsx', index=False)

# %%
# 특성 중요도 출력
print(xgb.feature_importances_)

# 특성 중요도 시각화
from xgboost import plot_importance
plot_importance(xgb)

# %%
# https://dacon.io/competitions/official/235736/codeshare/2877?page=1&dtype=recent

# %%
# print(zero_time)
# for i in zero_time:
#     print(i)

# %%
# # 첫 번째 데이터로 모델 학습
# model = xgb.XGBRegressor()
# model.fit(X_train1, y_train1)

# # 두 번째 데이터로 모델 추가 학습
# model.fit(X_train2, y_train2, xgb_model=model.get_booster())
